# %%
# Fix tax table so rank and taxonomy characteritics look nicer

# %%
library(reshape)
library(ggplot2)
library(phyloseq)
library(dplyr)

# %%
ps = import_biom("WB2016_OTU_table-new/feature-table-metaD-tax_json.biom" , parseFunction = parse_taxonomy_default)

# %%
head(tax_table(ps))
# Out:
#                                  Rank1       Rank2
# 86f7e172d4a477ac548274d7cf30cf16 d__Bacteria p__Actinobacteriota
# 75c5a7d1de33ad872da2331e8a605c45 d__Bacteria p__Proteobacteria
# 4129a88675d97baeb6afd72e704e018b d__Bacteria p__Actinobacteriota
# 154a339ce8de9cb6ace77dbd1bbc6637 d__Bacteria p__Actinobacteriota
# 4c31de261384e0253e628daad94ff8a1 d__Bacteria p__Actinobacteriota
# 72feaa010a322204f5731080c78374d8 d__Bacteria p__Verrucomicrobiota
#                                  Rank3                  Rank4
# 86f7e172d4a477ac548274d7cf30cf16 c__Actinobacteria      o__Micrococcales
# 75c5a7d1de33ad872da2331e8a605c45 c__Alphaproteobacteria o__Rhizobiales
# 4129a88675d97baeb6afd72e704e018b c__Actinobacteria      o__Corynebacteriales
# 154a339ce8de9cb6ace77dbd1bbc6637 c__Actinobacteria      o__Corynebacteriales
# 4c31de261384e0253e628daad94ff8a1 c__Actinobacteria      o__Frankiales
# 72feaa010a322204f5731080c78374d8 c__Verrucomicrobiae    o__Chthoniobacterales
#                                  Rank5
# 86f7e172d4a477ac548274d7cf30cf16 f__Micrococcaceae
# 75c5a7d1de33ad872da2331e8a605c45 f__Xanthobacteraceae
# 4129a88675d97baeb6afd72e704e018b f__Mycobacteriaceae
# 154a339ce8de9cb6ace77dbd1bbc6637 f__Mycobacteriaceae
# 4c31de261384e0253e628daad94ff8a1 f__Geodermatophilaceae
# 72feaa010a322204f5731080c78374d8 f__Chthoniobacteraceae
#                                  Rank6
# 86f7e172d4a477ac548274d7cf30cf16 NA
# 75c5a7d1de33ad872da2331e8a605c45 g__Bradyrhizobium
# 4129a88675d97baeb6afd72e704e018b g__Mycobacterium
# 154a339ce8de9cb6ace77dbd1bbc6637 g__Mycobacterium
# 4c31de261384e0253e628daad94ff8a1 g__Blastococcus
# 72feaa010a322204f5731080c78374d8 g__Candidatus_Udaeobacter
#                                  Rank7
# 86f7e172d4a477ac548274d7cf30cf16 NA
# 75c5a7d1de33ad872da2331e8a605c45 NA
# 4129a88675d97baeb6afd72e704e018b NA
# 154a339ce8de9cb6ace77dbd1bbc6637 NA
# 4c31de261384e0253e628daad94ff8a1 s__uncultured_bacterium
# 72feaa010a322204f5731080c78374d8 NA

# %%
##Fixing the tax_table object to "clean-up" the column names

x = data.frame(tax_table(ps))
# Making a dummy variable to store the taxonomy data

colnames(x) = c("Domain", "Phylum", "Class", "Order", "Family", "Genus", "Species")
# Assigning the proper column names instead of SILVA ranks

x$Domain = gsub("d__", "", as.character(x$Domain))
x$Phylum = gsub("p__", "", as.character(x$Phylum))
x$Class = gsub("c__", "", as.character(x$Class))
x$Order = gsub("o__", "", as.character(x$Order))
x$Family = gsub("f__", "", as.character(x$Family))
x$Genus = gsub("g__", "", as.character(x$Genus))
x$Species = gsub("s__", "", as.character(x$Species))
# Substituting the characters we don't want with nothing in the taxonomy

x=tax_table(as.matrix(x,dimnames=list(row.names(x),colnames(x))))
# Turning it into a taxonomy table, while saving the rownames and column names
tax_table(ps)=x
# Reassigning the taxonomy table in ps_xxx to the new modified one

head(tax_table(ps))
# Check for success
# Out:
#                                  Domain   Phylum            Class
# 86f7e172d4a477ac548274d7cf30cf16 Bacteria Actinobacteriota  Actinobacteria
# 75c5a7d1de33ad872da2331e8a605c45 Bacteria Proteobacteria    Alphaproteobacteria
# 4129a88675d97baeb6afd72e704e018b Bacteria Actinobacteriota  Actinobacteria
# 154a339ce8de9cb6ace77dbd1bbc6637 Bacteria Actinobacteriota  Actinobacteria
# 4c31de261384e0253e628daad94ff8a1 Bacteria Actinobacteriota  Actinobacteria
# 72feaa010a322204f5731080c78374d8 Bacteria Verrucomicrobiota Verrucomicrobiae
#                                  Order              Family
# 86f7e172d4a477ac548274d7cf30cf16 Micrococcales      Micrococcaceae
# 75c5a7d1de33ad872da2331e8a605c45 Rhizobiales        Xanthobacteraceae
# 4129a88675d97baeb6afd72e704e018b Corynebacteriales  Mycobacteriaceae
# 154a339ce8de9cb6ace77dbd1bbc6637 Corynebacteriales  Mycobacteriaceae
# 4c31de261384e0253e628daad94ff8a1 Frankiales         Geodermatophilaceae
# 72feaa010a322204f5731080c78374d8 Chthoniobacterales Chthoniobacteraceae
#                                  Genus                  Species
# 86f7e172d4a477ac548274d7cf30cf16 NA                     NA
# 75c5a7d1de33ad872da2331e8a605c45 Bradyrhizobium         NA
# 4129a88675d97baeb6afd72e704e018b Mycobacterium          NA
# 154a339ce8de9cb6ace77dbd1bbc6637 Mycobacterium          NA
# 4c31de261384e0253e628daad94ff8a1 Blastococcus           uncultured_bacterium
# 72feaa010a322204f5731080c78374d8 Candidatus_Udaeobacter NA

# %%
sample_data(ps)[1:10]
# Out:
#               BETUPAP_Seedling_Dens_m2 Broadleaf_BA Broadleaf_Biomass
# Multicom
# WB16-01-L-M-2 0                        0            0
# WB16-01-L-O-2 0                        0            0
# WB16-01-S-M-2 0                        0            0
# WB16-01-S-O-1 0                        0            0
# WB16-02-L-M-2 0                        0            0
# WB16-02-L-O-1 0                        0            0
# WB16-02-S-M-2 0                        0.004600189  2.278154461
# WB16-03-L-M-1 0                        0            0
# WB16-03-L-O-2 0                        0            0
#               Broadleaf_Seedling_Dens_m2 Broadleaf_stems CEC   CMD_Ann_19812010
# Multicom
# WB16-01-L-M-2 0.283333333                0               70.15 139
# WB16-01-L-O-2 0.283333333                0               5.36  139
# WB16-01-S-M-2 0                          0               81.08 139
# WB16-01-S-O-1 0                          0               140.4 139
# WB16-02-L-M-2 0.014285714                0               6.12  140
# WB16-02-L-O-1 0.014285714                0                     140
# WB16-02-S-M-2 0.282142857                285.71429       39.03 140
# WB16-03-L-M-1 1.957142857                0               26.09 133
# WB16-03-L-O-2 1.957142857                0               14.16 133
#               CMD_Ann_19912017 CMD_Y CMD_Y.1 ⋯ Understory_Conifer_Stems_Ha_Live
# Multicom                                     ⋯
# WB16-01-L-M-2 148              160   173     ⋯ 0
# WB16-01-L-O-2 148              160   173     ⋯ 0
# WB16-01-S-M-2 148              158   173     ⋯ 0
# WB16-01-S-O-1 148              158   173     ⋯ 0
# WB16-02-L-M-2 146              114   166     ⋯ 0
# WB16-02-L-O-1 146              114   166     ⋯ 0
# WB16-02-S-M-2 146              114   166     ⋯ 0
# WB16-03-L-M-1 143              168   136     ⋯ 0
# WB16-03-L-O-2 143              168   136     ⋯ 0
#               Understory_Stems_Ha_Live Understory_Total_Biomass_kg_Ha_Live
# Multicom
# WB16-01-L-M-2 0                        0
# WB16-01-L-O-2 0                        0
# WB16-01-S-M-2 0                        0
# WB16-01-S-O-1 0                        0
# WB16-02-L-M-2 0                        0
# WB16-02-L-O-1 0                        0
# WB16-02-S-M-2 285.71429                2.278154461
# WB16-03-L-M-1 0                        0
# WB16-03-L-O-2 0                        0
#               Unknown_Cover Vascular_Richness fwd_barcode jitterx
# Multicom                                      GACACTGA
# WB16-01-L-M-2 0             12                GCTCTAGT    -0.055477593
# WB16-01-L-O-2 0             12                GTCAGATA    -0.055477593
# WB16-01-S-M-2 0             7                 GCTCTAGT    -0.055477593
# WB16-01-S-O-1 0             7                 CGTGAGTG    -0.055477593
# WB16-02-L-M-2 0             15                CTACTATA    -0.842046699
# WB16-02-L-O-1 0             15                GACACCGT    -0.842046699
# WB16-02-S-M-2 0             12                ACTATCTG    -0.842046699
# WB16-03-L-M-1 0             17                ACGTCTCG    -0.973875266
# WB16-03-L-O-2 0             17                GTCAGATA    -0.973875266
#               jittery      pH   rev_barcode
# Multicom                        AACGCTGA
# WB16-01-L-M-2 -0.441148671 7.12 ATAGTACC
# WB16-01-L-O-2 -0.441148671 6.57 CGAGCGAC
# WB16-01-S-M-2 -0.441148671 6    GCGTATAC
# WB16-01-S-O-1 -0.441148671 6.19 TGAGTACG
# WB16-02-L-M-2 -0.081523031 6.22 CGAGAGTT
# WB16-02-L-O-1 -0.081523031      AACGCTGA
# WB16-02-S-M-2 -0.081523031 6.02 GATCTACG
# WB16-03-L-M-1 -0.652809098 5.81 CTCGACTT
# WB16-03-L-O-2 -0.652809098 5.58 TCTCTATG

# %%
saveRDS(ps, "ps.CERANR")

# %%
ps = readRDS("ps.CERANR")

# %%
colnames(sample_data(ps))
# Out:
#   [1] "BETUPAP_Seedling_Dens_m2"
#   [2] "Broadleaf_BA"
#   [3] "Broadleaf_Biomass"
#   [4] "Broadleaf_Seedling_Dens_m2"
#   [5] "Broadleaf_stems"
#   [6] "CEC"
#   [7] "CMD_Ann_19812010"
#   [8] "CMD_Ann_19912017"
#   [9] "CMD_Y"
#  [10] "CMD_Y-1"
#  [11] "CMD_Y-1_Mean_Departure"
#  [12] "CMD_Y1"
#  [13] "CMD_Y1_Mean_Departure"
#  [14] "CMD_Y2"
#  [15] "CMD_Y2_Mean_Departure"
#  [16] "CMD_Y_Mean_Departure"
#  [17] "Ca"
#  [18] "Clay"
#  [19] "Conifer_BA"
#  [20] "Conifer_Biomass"
#  [21] "Conifer_Seedling_Dens_m2"
#  [22] "Conifer_stems"
#  [23] "EC"
#  [24] "Ecosite_Name"
#  [25] "Ecosite_Phase"
#  [26] "Elevation"
#  [27] "Forb_Cover"
#  [28] "Forb_Richness"
#  [29] "Graminoid_Cover"
#  [30] "Graminoid_Richness"
#  [31] "Indic_Class"
#  [32] "Interval"
#  [33] "K"
#  [34] "LARILAR_Seedling_Dens_m2"
#  [35] "Land_Class"
#  [36] "Latitude"
#  [37] "Leading_Species"
#  [38] "Lichen_Cover"
#  [39] "Lichen_Richness"
#  [40] "Load_Rotten_nologs"
#  [41] "Load_Sound_nologs"
#  [42] "Longitude"
#  [43] "MAP_Ann_19812010"
#  [44] "MAT_Ann_19812010"
#  [45] "Mean_Overstory_Density_Pct"
#  [46] "Mg"
#  [47] "Mineral_Soil"
#  [48] "Moisture_Numeric"
#  [49] "Moisture_Regime"
#  [50] "Na"
#  [51] "No_Trees"
#  [52] "Nonvascular_Cover"
#  [53] "Nonvascular_Richness"
#  [54] "Old_Sites"
#  [55] "Old_Year"
#  [56] "Organic_Matter"
#  [57] "Overstory_BA_Ha_Live"
#  [58] "Overstory_Broadleaf_BA_Ha_Live"
#  [59] "Overstory_Broadleaf_Biomass_kg_Ha_Live"
#  [60] "Overstory_Broadleaf_Stems_Ha_Live"
#  [61] "Overstory_Conifer_BA_Ha_Live"
#  [62] "Overstory_Conifer_Biomass_kg_Ha_Live"
#  [63] "Overstory_Conifer_Stems_Ha_Live"
#  [64] "Overstory_Stems_Ha_Live"
#  [65] "Overstory_Total_Biomass_kg_Ha_Live"
#  [66] "PCt_Conifer_Seedlings"
#  [67] "PICEGLA_Seedling_Dens_m2"
#  [68] "PICEMAR_Seedling_Dens_m2"
#  [69] "PICE_Seedling_Dens_m2"
#  [70] "PINUBAN_Seedling_Dens_m2"
#  [71] "POPUBAL_Seedling_Dens_m2"
#  [72] "POPUTRE_Seedling_Dens_m2"
#  [73] "Pair_ID"
#  [74] "Pct_Conifer_BA"
#  [75] "Pct_Conifer_Biomass"
#  [76] "Pct_Conifer_Stems"
#  [77] "Recent_Interval"
#  [78] "Recent_Year"
#  [79] "Sand"
#  [80] "Shrub_Cover"
#  [81] "Shrub_Richness"
#  [82] "Shrubs_m2"
#  [83] "Silt"
#  [84] "Site_ID"
#  [85] "Soil_layer"
#  [86] "TC"
#  [87] "TSLF_At_Sample"
#  [88] "Total N"
#  [89] "Total S"
#  [90] "Total_BA"
#  [91] "Total_Biomass"
#  [92] "Total_CWD_Load_Kg_m2"
#  [93] "Total_Load_Rotten"
#  [94] "Total_Load_Sound"
#  [95] "Total_Seedling_Dens_m2"
#  [96] "Total_Veg_Richness"
#  [97] "Total_stems"
#  [98] "Understocked"
#  [99] "Understory_BA_Ha_Live"
# [100] "Understory_Broadleaf_BA_Ha_Live"
# [101] "Understory_Broadleaf_Biomass_kg_Ha_Live"
# [102] "Understory_Broadleaf_Stems_Ha_Live"
# [103] "Understory_Conifer_BA_Ha_Live"
# [104] "Understory_Conifer_Biomass_kg_Ha_Live"
# [105] "Understory_Conifer_Stems_Ha_Live"
# [106] "Understory_Stems_Ha_Live"
# [107] "Understory_Total_Biomass_kg_Ha_Live"
# [108] "Unknown_Cover"
# [109] "Vascular_Richness"
# [110] "fwd_barcode"
# [111] "jitterx"
# [112] "jittery"
# [113] "pH"
# [114] "rev_barcode"

# %%
sample_data(ps)$pH = as.factor(sample_data(ps)$pH)
sample_data(ps)$Total_stems = as.factor(sample_data(ps)$Total_stems)

sample_data(ps)$Recent_Interval = as.factor(sample_data(ps)$Recent_Interval)
sample_data(ps)$TSLF_At_Sample = as.factor(sample_data(ps)$TSLF_At_Sample)
sample_data(ps)$pH = as.factor(sample_data(ps)$pH)
sample_data(ps)$pH = as.factor(sample_data(ps)$pH)

# %%
saveRDS(ps, "ps.CERANR")
